# %%
age = 21
year = 2026

print("My age is:", age)
print("Current year is:", year)

sum_value = age + year
print("Sum of age and year:", sum_value)
# Out:
# My age is: 21
# Current year is: 2026
# Sum of age and year: 2047
