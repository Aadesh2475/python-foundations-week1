# %%
subjects = ["Python", "DBMS", "Web Development", "AI"]

print("Subjects in internship:")
print(subjects)
print("First subject:", subjects[0])

subjects.append("Machine Learning")
print("Updated subjects list:", subjects)
